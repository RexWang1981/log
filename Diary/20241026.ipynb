# %% [markdown]
# # 2024-10-26 Rex个人笔记
# _2024-10-26 | Rex Wang_

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

airflow=pd.read_excel(r'C:\Users\100034133\Desktop\02 HILO-Lite\Test data 2024-10-23 air flow test data\HILO LITE  & ECM Airflow test data 1300rpm 200-34 2024-10-23.xlsx')
airflow
# Out:
#    1- ECM 12 254 -25度 1300RPM Unnamed: 1           Unnamed: 2      Unnamed: 3  \
# 0                  speed(rpm)        No.  Static pressure(pa)  Air flow(m3/h)
# 1                        1290          1                    0           817.3
# 2                        1258          2                 15.3             662
# 3                        1241          3                 18.4           601.2
# 4                        1260          4                 21.2           521.7
# 5                        1268          5                 21.7           453.3
# 6                        1220          6                 26.7           400.3
# 7                        1550          7                 37.6           292.8
# 8                        1086          8                 50.3           131.4
# 9                        1074          9                 52.3            97.8
# 10                       1062         10                 52.5            98.3
# ...
